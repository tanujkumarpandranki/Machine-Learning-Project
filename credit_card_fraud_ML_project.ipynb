# %% [markdown]
# <a href="https://colab.research.google.com/github/tanujkumarpandranki/Machine-Learning-Project/blob/main/credit_card_fraud_ML_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f2e08ee2-ca14-43ab-85c1-5adf9661806c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f2e08ee2-ca14-43ab-85c1-5adf9661806c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
data = pd.read_csv("credit_card_fraud_with_missing.csv")

# %%
data.head()
# Out:
#    transaction_id  amount  transaction_hour merchant_category  \
# 0               1   84.47                22       Electronics
# 1               2  541.82                 3            Travel
# 2               3  237.01                17           Grocery
# 3               4  164.33                 4           Grocery
# 4               5   30.53                15              Food
#
#    foreign_transaction  location_mismatch  device_trust_score  \
# 0                    0                  0                66.0
# 1                    1                  0                87.0
# 2                    0                  0                49.0
# 3                    0                  1                72.0
# 4                    0                  0                79.0
#
#    velocity_last_24h  cardholder_age  is_fraud
# 0                  3              40         0
# 1                  1              64         0
# 2                  1              61         0
# ...

# %%
data.shape
# Out:
# (10000, 10)

# %%
data.dtypes
# Out:
# transaction_id           int64
# amount                 float64
# transaction_hour         int64
# merchant_category       object
# foreign_transaction      int64
# location_mismatch        int64
# device_trust_score     float64
# velocity_last_24h        int64
# cardholder_age           int64
# is_fraud                 int64
# dtype: object

# %%
data.describe()
# Out:
#        transaction_id       amount  transaction_hour  foreign_transaction  \
# count     10000.00000  9700.000000      10000.000000         10000.000000
# mean       5000.50000   175.604813         11.593300             0.097800
# std        2886.89568   175.351299          6.922708             0.297059
# min           1.00000     0.000000          0.000000             0.000000
# 25%        2500.75000    50.570000          6.000000             0.000000
# 50%        5000.50000   121.850000         12.000000             0.000000
# 75%        7500.25000   241.635000         18.000000             0.000000
# max       10000.00000  1471.040000         23.000000             1.000000
#
#        location_mismatch  device_trust_score  velocity_last_24h  \
# count       10000.000000         9800.000000       10000.000000
# mean            0.085700           61.831224           2.008900
# std             0.279935           21.497795           1.432559
# ...

# %%
data.isnull().sum()
# Out:
# transaction_id           0
# amount                 300
# transaction_hour         0
# merchant_category      200
# foreign_transaction      0
# location_mismatch        0
# device_trust_score     200
# velocity_last_24h        0
# cardholder_age           0
# is_fraud                 0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(data.isnull(), cbar=False)
plt.title("Missing Values Heatmap")
plt.show()

# %%
data['amount'].fillna(data['amount'].mean(), inplace=True)
# Out:
# /tmp/ipython-input-828/2281527189.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['amount'].fillna(data['amount'].mean(), inplace=True)

# %%
data['amount']
# Out:
# 0        84.47
# 1       541.82
# 2       237.01
# 3       164.33
# 4        30.53
#          ...
# 9995    350.91
# 9996    410.04
# 9997    527.75
# 9998     91.20
# 9999     44.06
# Name: amount, Length: 10000, dtype: float64

# %%
data.isnull().sum()
# Out:
# transaction_id           0
# amount                   0
# transaction_hour         0
# merchant_category      200
# foreign_transaction      0
# location_mismatch        0
# device_trust_score     200
# velocity_last_24h        0
# cardholder_age           0
# is_fraud                 0
# dtype: int64

# %%
data['device_trust_score'].fillna(data['device_trust_score'].median(), inplace=True)
# Out:
# /tmp/ipython-input-828/1380041321.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['device_trust_score'].fillna(data['device_trust_score'].median(), inplace=True)

# %%
data.isnull().sum()
# Out:
# transaction_id           0
# amount                   0
# transaction_hour         0
# merchant_category      200
# foreign_transaction      0
# location_mismatch        0
# device_trust_score       0
# velocity_last_24h        0
# cardholder_age           0
# is_fraud                 0
# dtype: int64

# %%
data['merchant_category'].fillna('Unknown', inplace=True)
# Out:
# /tmp/ipython-input-828/2150663888.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['merchant_category'].fillna('Unknown', inplace=True)

# %%
data.isnull().sum()
# Out:
# transaction_id         0
# amount                 0
# transaction_hour       0
# merchant_category      0
# foreign_transaction    0
# location_mismatch      0
# device_trust_score     0
# velocity_last_24h      0
# cardholder_age         0
# is_fraud               0
# dtype: int64

# %%
sns.heatmap(data.isnull(), cbar=False)
plt.title("Missing Values Heatmap")
plt.show()

# %%
data["is_fraud"].value_counts()
# Out:
# is_fraud
# 0    9849
# 1     151
# Name: count, dtype: int64

# %%
sns.countplot(x='is_fraud',data=data)
plt.title("Fraud vs Non-Fraud Count")
plt.show()

# %%
print("Fraud Percentage:", data['is_fraud'].mean() * 100)
# Out:
# Fraud Percentage: 1.51

# %%
data.groupby('is_fraud')['amount'].describe()
# Out:
#            count        mean         std   min    25%     50%      75%  \
# is_fraud
# 0         9849.0  174.995283  171.264703  0.00  52.32  126.85  236.260
# 1          151.0  215.361553  246.653565  0.11  42.62  119.03  337.975
#
#               max
# is_fraud
# 0         1471.04
# 1         1185.07

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='is_fraud', y='amount', data=data)
plt.title("Transaction Amount vs Fraud")
plt.show()

# %%
fraud_by_hour = data.groupby('transaction_hour')['is_fraud'].mean()

fraud_by_hour.plot(kind='bar', figsize=(10,5))
plt.title("Fraud Rate by Hour")
plt.ylabel("Fraud Rate")
plt.show()

# %%
data.groupby('merchant_category')['is_fraud'].agg(['count','mean'])
# Out:
#                    count      mean
# merchant_category
# Clothing            2006  0.011964
# Electronics         1879  0.012241
# Food                2064  0.016957
# Grocery             1899  0.020011
# Travel              1952  0.014857
# Unknown              200  0.010000

# %%
merchant_fraud = data.groupby('merchant_category')['is_fraud'].mean().sort_values(ascending=False)

merchant_fraud.plot(kind='bar', figsize=(10,5))
plt.title("Fraud Rate by Merchant Category")
plt.show()

# %%
fraud_rate = data.groupby('foreign_transaction')['is_fraud'].mean()

fraud_rate.plot(kind='bar')
plt.ylabel("Fraud Rate")
plt.title("Fraud Rate by Foreign Transaction")
plt.show()

# %%
pd.crosstab(data['location_mismatch'], data['is_fraud'])
# Out:
# is_fraud              0   1
# location_mismatch
# 0                  9064  79
# 1                   785  72

# %%
data.groupby('location_mismatch')['is_fraud'].sum()
# Out:
# location_mismatch
# 0    79
# 1    72
# Name: is_fraud, dtype: int64

# %%
sns.countplot(x='location_mismatch', hue='is_fraud', data=data)
plt.title("Location Mismatch vs Fraud")
plt.show()

# %%
data.groupby('is_fraud')['device_trust_score'].describe()
# Out:
#            count       mean        std   min   25%   50%   75%   max
# is_fraud
# 0         9849.0  62.195756  21.149238  25.0  44.0  62.0  80.0  99.0
# 1          151.0  38.278146  16.057048  25.0  29.0  32.0  38.5  99.0

# %%
sns.boxplot(x='is_fraud', y='device_trust_score', data=data)
plt.title("Device Trust Score vs Fraud")
plt.show()

# %%
data.groupby('is_fraud')['velocity_last_24h'].describe()
# Out:
#            count      mean       std  min  25%  50%  75%  max
# is_fraud
# 0         9849.0  1.990557  1.415366  0.0  1.0  2.0  3.0  9.0
# 1          151.0  3.205298  1.953861  0.0  2.0  3.0  5.0  7.0

# %%
sns.boxplot(x='is_fraud', y='velocity_last_24h', data=data)
plt.title("Velocity vs Fraud")
plt.show()

# %%
numeric_data = data.select_dtypes(include=['number'])

sns.heatmap(numeric_data.corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Matrix")
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from imblearn.pipeline import Pipeline as ImbPipeline
from sklearn.impute import SimpleImputer
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, classification_report, roc_auc_score

# %%
X = data.drop(columns=['is_fraud','transaction_id'])
y = data['is_fraud']

# %%
numeric_features = X.select_dtypes(include=['int64','float64']).columns
categorical_features = X.select_dtypes(include=['object']).columns

# %%
numeric_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

# %%
categorical_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('encoder', OneHotEncoder(handle_unknown='ignore'))
])

# %%
preprocessor = ColumnTransformer([
    ('numerical', numeric_pipeline, numeric_features),
    ('categorical', categorical_pipeline, categorical_features)
])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.2,stratify=y,random_state=42)

# %%
neg = sum(y_train == 0)
pos = sum(y_train == 1)

scale_weight = neg / pos

print("scale_pos_weight:", scale_weight)
# Out:
# scale_pos_weight: 65.11570247933884

# %%
model_pipeline = ImbPipeline([
    ('preprocessing', preprocessor),
    ('classifier', XGBClassifier(
        n_estimators=300,
        learning_rate=0.05,
        max_depth=5,
        scale_pos_weight=scale_weight,
        random_state=42,
        use_label_encoder=False,
        eval_metric='logloss'
    ))
])

# %%
model_pipeline.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:23:54] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(transformers=[('numerical',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   Index(['amount', 'transaction_hour', 'foreign_transaction',
#        'location_mismatch', 'device_trust_score', 'velocity_last_24h',
#        'cardholder_age'],
#       dtype='object')),
# ...

# %%
y_pred = model_pipeline.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
print("ROC-AUC:", roc_auc_score(y_test, y_pred))
# Out:
# Accuracy: 0.9995
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1970
#            1       1.00      0.97      0.98        30
#
#     accuracy                           1.00      2000
#    macro avg       1.00      0.98      0.99      2000
# weighted avg       1.00      1.00      1.00      2000
#
# ROC-AUC: 0.9833333333333334
